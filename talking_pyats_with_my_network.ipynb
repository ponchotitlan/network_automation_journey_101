# %% [markdown]
# # CLI automation with Cisco pyATS 🚀
#
# **pyATS** (Python Automated Test System) is a Cisco-developed Python framework for **network test automation and verification**. It helps network engineers and developers **automate configuration, testing, and validation** on real and virtual devices.
#
# ---
#
# ### 🧩 Components
#
# - **pyATS Core** 🔹
#   The foundation for network automation, managing devices, connections, and test execution.
#
# - **Genie** 🧪
#   Cisco’s parsing and abstraction library. Converts raw device output into structured data (facts) and provides configuration models.
#
# - **Unicon** 🔌
#   Handles **device connectivity** (SSH, Telnet, console) and session management.
#
# - **Testbeds** 🗺️
#   YAML-based definitions of devices, connections, credentials, and topology for consistent automation.
#
# - **Ops and Conf Libraries** ⚙️
#   - **Ops**: Learn device state, interfaces, routing tables, etc.
#   - **Conf**: Build or rollback configurations programmatically.
#
# ---
#
# ### 🌟 Benefits
#
# - ✅ Automate repetitive network tasks
# - ✅ Test configurations and verify device state
# - ✅ Generate dry-run config previews and diffs
# - ✅ Multi-vendor and multi-platform support (with Genie)
# - ✅ Safe rollback and candidate configuration support on IOS-XR and other platforms
#
# ---
#
# 🔁 First of all, create a virtual environment with the following commands:

# %%
# !python3 -m venv .venv && source .venv/bin/activate
# !pip install -r requirements.txt

# %% [markdown]
# ### 1️⃣ Create and validate my testbed
# Now, let's create a `topology.yaml` file where we specify which are all our devices, and how to connect to them.</br>
# We then proceed to validate that file, and we can even run a basic connectivity attempt on each of the included devices.

# %%
# !pyats validate testbed pyATS/testbed.yaml --connect
# Out:
# Loading testbed file: pyATS/testbed.yaml
# --------------------------------------------------------------------------------
#
# Testbed Name:
#     NetworkAutoDemo
#
# Testbed Devices:
# .
# `-- sandbox1 [iosxr/ASR9K]
#
# YAML Lint Messages
# ------------------
#
# Connection Check
# ----------------
#
#     note that connection checks are not 100% accurate - it does not take
#     into account that connection implementations may choose to interpret
#     the entire connection block differently.
#
#     For example - Unicon autouses A/B console/standby, but does not allow
#     explicit connection to B.
#
#  - sandbox1/cli             [PASSED]
#
# Warning Messages
# ----------------
#  - Device 'sandbox1' has no interface definitions

# %% [markdown]
# ### 2️⃣ Connect to my device and retrieve raw/parsed configs
# Now, let's roll our sleeves a little bit and get hands-on coding!</br>
# Let's connect to our device using the info in our `testbed.yaml` file.</br>
# pyATS will use the `unicon` library and the information from the yaml file to attempt to connect to the device `sandbox1`.

# %%
import json
from pyats.topology import loader

# %%
testbed = loader.load('pyATS/testbed.yaml')
device = testbed.devices['sandbox1']

device.connect()
print("✅ Connected successfully to", device.name)
# Out:
# 2025-11-12 10:53:28,492: %UNICON-INFO: +++ sandbox1 logfile sandbox1-cli-1762944808.log +++
#
# 2025-11-12 10:53:28,492: %UNICON-INFO: +++ Unicon plugin iosxr (unicon.plugins.iosxr) +++
#
# Hello there! Hoping you are having a great day
# ... Welcome to 'ios',
# your favorite CISCO.IOSXR.IOSXR Sandbox
#
#
#
# 2025-11-12 10:53:30,054: %UNICON-INFO: +++ connection to spawn: ssh -l admin 131.226.217.150 -p 22, id: 4679754576 +++
#
# 2025-11-12 10:53:30,055: %UNICON-INFO: connection to sandbox1
# (admin@131.226.217.150) Password:
#
#
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:53:31,000: %UNICON-INFO: Storing credentials from default as current_credentials
#
# 2025-11-12 10:53:31,002: %UNICON-WARNING: Invalid hostname detected: found ios, expected sandbox1
#
# 2025-11-12 10:53:31,003: %UNICON-INFO: +++ initializing handle +++
#
# 2025-11-12 10:53:31,192: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'terminal length 0' +++
# terminal length 0
# Wed Nov 12 11:40:56.384 UTC
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:53:31,736: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'terminal width 0' +++
# terminal width 0
# Wed Nov 12 11:40:56.930 UTC
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:53:32,089: %UNICON-INFO: +++ sandbox1 with via 'cli': configure +++
# configure terminal
# Wed Nov 12 11:40:57.463 UTC
# RP/0/RP0/CPU0:ios(config)#no logging console
# RP/0/RP0/CPU0:ios(config)#logging console disable
# RP/0/RP0/CPU0:ios(config)#line console
# RP/0/RP0/CPU0:ios(config-line)#exec-timeout 0 0
# RP/0/RP0/CPU0:ios(config-line)#absolute-timeout 0
# RP/0/RP0/CPU0:ios(config-line)#session-timeout 0
# RP/0/RP0/CPU0:ios(config-line)#line default
# RP/0/RP0/CPU0:ios(config-line)#exec-timeout 0 0
# RP/0/RP0/CPU0:ios(config-line)#absolute-timeout 0
# RP/0/RP0/CPU0:ios(config-line)#session-timeout 0
# RP/0/RP0/CPU0:ios(config-line)#commit
# Wed Nov 12 11:40:59.906 UTC
# RP/0/RP0/CPU0:ios(config-line)#end
# RP/0/RP0/CPU0:ios#
# ✅ Connected successfully to sandbox1

# %% [markdown]
# 🔌 Lovely. Now, we want to get **information about the interfaces in this device**.</br>
# For this, let's use the good-old `show ip interfaces brief`.

# %%
device.execute("show ip interface brief")
# Out:
# 2025-11-12 09:32:43,037: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ip interface brief' +++
# show ip interface brief
# Wed Nov 12 10:20:08.849 UTC
#
# Interface                      IP-Address      Status          Protocol Vrf-Name
# Loopback100                    1.1.1.100       Up              Up       default
# Loopback555                    unassigned      Up              Up       default
# MgmtEth0/RP0/CPU0/0            10.10.20.175    Up              Up       default
# GigabitEthernet0/0/0/0         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/1         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/2         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/3         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/4         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/5         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/6         unassigned      Shutdown        Down     default
# RP/0/RP0/CPU0:ios#
# '\rWed Nov 12 10:20:08.849 UTC\r\n\r\nInterface                      IP-Address      Status          Protocol Vrf-Name\r\nLoopback100                    1.1.1.100       Up              Up       default \r\nLoopback555                    unassigned      Up              Up       default \r\nMgmtEth0/RP0/CPU0/0            10.10.20.175    Up              Up       default \r\nGigabitEthernet0/0/0/0         unassigned      Shutdown        Down     default \r\nGigabitEthernet0/0/0/1         unassigned      Shutdown        Down     default \r\nGigabitEthernet0/0/0/2         unassigned      Shutdown        Down     default \r\nGigabitEthernet0/0/0/3         unassigned      Shutdown        Down     default \r\nGigabitEthernet0/0/0/4         unassigned      Shutdown        Down     default \r\nGigabitEthernet0/0/0/5         unassigned      Shutdown        Down     default \r\nGigabitEthernet0/0/0/6         unassigned      Shutdown        Down     default'

# %% [markdown]
# 🔀 Beautiful. But let's imagine that I want to work with this info and get the exact names and IP addresses only. It's gonna be a bit of a regex or TextFMS burden, isn't it?</br></br>
# **Let's use [the built-in Genie parses instead! 🧞](https://pubhub.devnetcloud.com/media/genie-feature-browser/docs/#/parsers)**

# %%
genie_parsed_interfaces = device.parse("show ip interface brief")
print(json.dumps(genie_parsed_interfaces,indent=4))
# Out:
# 2025-11-12 10:57:51,089: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ip interface brief' +++
# show ip interface brief
# Wed Nov 12 11:45:16.272 UTC
#
# Interface                      IP-Address      Status          Protocol Vrf-Name
# Loopback100                    1.1.1.100       Up              Up       default
# Loopback200                    unassigned      Up              Up       default
# Loopback300                    unassigned      Up              Up       default
# Loopback555                    unassigned      Up              Up       default
# MgmtEth0/RP0/CPU0/0            10.10.20.175    Up              Up       default
# GigabitEthernet0/0/0/0         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/1         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/2         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/3         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/4         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/5         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/6         unassigned      Shutdown        Down     default
# RP/0/RP0/CPU0:ios#
# {
#     "interface": {
#         "Loopback100": {
#             "ip_address": "1.1.1.100",
#             "interface_status": "Up",
#             "protocol_status": "Up",
#             "vrf_name": "default"
#         },
#         "Loopback200": {
#             "ip_address": "unassigned",
#             "interface_status": "Up",
#             "protocol_status": "Up",
#             "vrf_name": "default"
#         },
#         "Loopback300": {
#             "ip_address": "unassigned",
#             "interface_status": "Up",
#             "protocol_status": "Up",
#             "vrf_name": "default"
#         },
#         "Loopback555": {
#             "ip_address": "unassigned",
#             "interface_status": "Up",
#             "protocol_status": "Up",
#             "vrf_name": "default"
#         },
#         "MgmtEth0/RP0/CPU0/0": {
#             "ip_address": "10.10.20.175",
#             "interface_status": "Up",
#             "protocol_status": "Up",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/0": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/1": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/2": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/3": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/4": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/5": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/6": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         }
#     }
# }

# %% [markdown]
# 🧞 That's better, isn't it? A beautiful Python dictionary to work with ...

# %% [markdown]
# ### 🧠 Config, learn and compare
#
# pyATS comes bundled with a powerful feature called `learn`. It allows us to take snapshots of a specific configuration of a device to later use them to compare changes.
# This is **[a series of CLI commands related to a specific feature](https://pubhub.devnetcloud.com/media/genie-feature-browser/docs/#/models)**, which are then parsed into an in-memory dictionary.</br></br>
# Now, let's learn **everything we can about our device's interfaces**.

# %%
learned_interfaces = device.learn("interface")
print(f"\n\n\n\n\n\n\n{json.dumps(learned_interfaces.to_dict(),indent=4)}")
# Out:
# 2025-11-12 11:01:52,177: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show vrf all detail' +++
# show vrf all detail
# Wed Nov 12 11:49:17.465 UTC
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 11:01:52,841: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show interface detail' +++
# show interface detail
# Wed Nov 12 11:49:18.070 UTC
# Loopback100 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: ***TEST LOOPBACK****
#   Internet address is 1.1.1.100/32
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:46:23
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback200 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:29:27
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback300 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:29:27
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback555 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: PRUEBA_KV
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:46:23
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Null0 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Null interface
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability 255/255, txload Unknown, rxload Unknown
#   Encapsulation Null,  loopback not set,
#   Last link flapped 00:46:52
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#
# MgmtEth0/RP0/CPU0/0 is up, line protocol is up
#   Interface state transitions: 3
#   Hardware is Management Ethernet, address is 0050.56bf.d307 (bia 0050.56bf.d307)
#   Internet address is 10.10.20.175/24
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Full-duplex, 1000Mb/s, CX, link type is autonegotiation
#   loopback not set,
#   Last link flapped 00:46:23
#   ARP type ARPA, ARP timeout 04:00:00
#   Last input 00:00:00, output 00:00:00
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 1 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      1855 packets input, 174034 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 1 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      1359 packets output, 314410 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      3 carrier transitions
#
# GigabitEthernet0/0/0/0 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.bb17 (bia 0050.56bf.bb17)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/1 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.1337 (bia 0050.56bf.1337)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/2 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.8181 (bia 0050.56bf.8181)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/3 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.afc9 (bia 0050.56bf.afc9)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/4 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.bedb (bia 0050.56bf.bedb)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/5 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.3ee8 (bia 0050.56bf.3ee8)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/6 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.ee29 (bia 0050.56bf.ee29)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
#
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 11:01:53,728: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ethernet tags' +++
# show ethernet tags
# Wed Nov 12 11:49:18.909 UTC
# St:    AD - Administratively Down, Dn - Down, Up - Up
# Ly:    L2 - Switched layer 2 service, L3 = Terminated layer 3 service,
# Xtra   C - Match on Cos, E  - Match on Ethertype, M - Match on source MAC
# -,+:   Ingress rewrite operation; number of tags to pop and push respectively
#
# Interface               St  MTU  Ly Outer            Inner            Xtra -,+
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 11:01:54,267: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show interfaces accounting' +++
# show interfaces accounting
# Wed Nov 12 11:49:19.540 UTC
# No accounting statistics available for Loopback100
#
# No accounting statistics available for Loopback200
#
# No accounting statistics available for Loopback300
#
# No accounting statistics available for Loopback555
#
# No accounting statistics available for Null0
#
# No accounting statistics available for GigabitEthernet0/0/0/0
#
# No accounting statistics available for GigabitEthernet0/0/0/1
#
# No accounting statistics available for GigabitEthernet0/0/0/2
#
# No accounting statistics available for GigabitEthernet0/0/0/3
#
# No accounting statistics available for GigabitEthernet0/0/0/4
#
# No accounting statistics available for GigabitEthernet0/0/0/5
#
# No accounting statistics available for GigabitEthernet0/0/0/6
#
# MgmtEth0/RP0/CPU0/0
#   Protocol              Pkts In         Chars In     Pkts Out        Chars Out
#   IPV4_UNICAST             1862           174578         1363           309920
#   ARP                        17             1020           18              756
#
#
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 11:01:54,934: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ipv4 vrf all interface' +++
# show ipv4 vrf all interface
# Wed Nov 12 11:49:20.121 UTC
# Loopback100 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet address is 1.1.1.100/32
#   MTU is 1500 (1500 is available to IP)
#   Helper address is not set
#   Directed broadcast forwarding is disabled
#   Outgoing access list is not set
#   Inbound  common access list is not set, access list is not set
#   Proxy ARP is disabled
#   ICMP redirects are never sent
#   ICMP unreachables are always sent
#   ICMP mask replies are never sent
#   Table Id is 0xe0000000
# Loopback200 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# Loopback300 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# Loopback555 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# MgmtEth0/RP0/CPU0/0 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet address is 10.10.20.175/24
#   MTU is 1514 (1500 is available to IP)
#   Helper address is not set
#   Directed broadcast forwarding is disabled
#   Outgoing access list is not set
#   Inbound  common access list is not set, access list is not set
#   Proxy ARP is disabled
#   ICMP redirects are never sent
#   ICMP unreachables are always sent
#   ICMP mask replies are never sent
#   Table Id is 0xe0000000
# GigabitEthernet0/0/0/0 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/1 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/2 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/3 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/4 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/5 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/6 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 11:01:55,597: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ipv6 vrf all interface' +++
# show ipv6 vrf all interface
# Wed Nov 12 11:49:20.801 UTC
# Loopback100 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback200 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback300 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback555 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# MgmtEth0/RP0/CPU0/0 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/0 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/1 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/2 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/3 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/4 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/5 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/6 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# RP/0/RP0/CPU0:ios#
#
#
#
#
#
#
#
# {
#     "context_manager": {},
#     "attributes": null,
#     "commands": null,
#     "connections": null,
#     "raw_data": false,
#     "info": {
#         "GigabitEthernet0/0/0/3": {
#             "description": "test",
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.afc9",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.afc9",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "GigabitEthernet0/0/0/2": {
#             "description": "test",
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.8181",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.8181",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "GigabitEthernet0/0/0/1": {
#             "description": "test",
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.1337",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.1337",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "Loopback555": {
#             "description": "PRUEBA_KV",
#             "oper_status": "up",
#             "mtu": 1500,
#             "enabled": true,
#             "bandwidth": 0,
#             "encapsulation": {
#                 "encapsulation": "loopback"
#             },
#             "ipv6": {
#                 "enabled": true
#             }
#         },
#         "Loopback100": {
#             "description": "***TEST LOOPBACK****",
#             "oper_status": "up",
#             "mtu": 1500,
#             "enabled": true,
#             "bandwidth": 0,
#             "ipv4": {
#                 "1.1.1.100/32": {
#                     "ip": "1.1.1.100",
#                     "prefix_length": "32"
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "loopback"
#             },
#             "ipv6": {
#                 "enabled": true
#             }
#         },
#         "GigabitEthernet0/0/0/6": {
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.ee29",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.ee29",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "GigabitEthernet0/0/0/5": {
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.3ee8",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.3ee8",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "GigabitEthernet0/0/0/4": {
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.bedb",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.bedb",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "GigabitEthernet0/0/0/0": {
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.bb17",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.bb17",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "MgmtEth0/RP0/CPU0/0": {
#             "type": "management ethernet",
#             "oper_status": "up",
#             "phys_address": "0050.56bf.d307",
#             "port_speed": "1000",
#             "mtu": 1514,
#             "enabled": true,
#             "mac_address": "0050.56bf.d307",
#             "auto_negotiate": true,
#             "duplex_mode": "full",
#             "bandwidth": 1000000,
#             "accounting": {
#                 "ipv4_unicast": {
#                     "pkts_in": 1862,
#                     "chars_in": 174578,
#                     "pkts_out": 1363,
#                     "chars_out": 309920
#                 },
#                 "arp": {
#                     "pkts_in": 17,
#                     "chars_in": 1020,
#                     "pkts_out": 18,
#                     "chars_out": 756
#                 }
#             },
#             "ipv4": {
#                 "10.10.20.175/24": {
#                     "ip": "10.10.20.175",
#                     "prefix_length": "24"
#                 }
#             },
#             "counters": {
#                 "in_pkts": 1855,
#                 "in_octets": 174034,
#                 "in_broadcast_pkts": 1,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 314410,
#                 "in_crc_errors": 0,
#                 "out_pkts": 1359,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 1,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": true
#             }
#         },
#         "Null0": {
#             "type": "null",
#             "oper_status": "up",
#             "mtu": 1500,
#             "enabled": true,
#             "bandwidth": 0,
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "null"
#             }
#         },
#         "Loopback300": {
#             "oper_status": "up",
#             "mtu": 1500,
#             "enabled": true,
#             "bandwidth": 0,
#             "encapsulation": {
#                 "encapsulation": "loopback"
#             },
#             "ipv6": {
#                 "enabled": true
#             }
#         },
#         "Loopback200": {
#             "oper_status": "up",
#             "mtu": 1500,
#             "enabled": true,
#             "bandwidth": 0,
#             "encapsulation": {
#                 "encapsulation": "loopback"
#             },
#             "ipv6": {
#                 "enabled": true
#             }
#         }
#     }
# }

# %% [markdown]
# 🔌 This is **way more** than a simple `show ip interface brief`, right?!

# %% [markdown]
# ⚡️ But now, let's create a new interface. We can do it either "manually":

# %%
device.configure('''
    interface Loopback401
    description "TechTilesDemo01"
''')
# Out:
# 2025-11-12 11:03:21,362: %UNICON-INFO: +++ sandbox1 with via 'cli': configure +++
# configure terminal
# Wed Nov 12 11:50:46.769 UTC
# RP/0/RP0/CPU0:ios(config)#
# RP/0/RP0/CPU0:ios(config)#    interface Loopback401
# RP/0/RP0/CPU0:ios(config-if)#    description "TechTilesDemo01"
# RP/0/RP0/CPU0:ios(config-if)#commit
# Wed Nov 12 11:50:47.815 UTC
# RP/0/RP0/CPU0:ios(config-if)#end
# RP/0/RP0/CPU0:ios#
# '\r\n\rRP/0/RP0/CPU0:ios(config)    interface Loopback401\r\n\rRP/0/RP0/CPU0:ios(config-if)    description "TechTilesDemo01"\r\n\rRP/0/RP0/CPU0:ios(config-if)commit\r\n\rWed Nov 12 11:50:47.815 UTC\r\nRP/0/RP0/CPU0:ios(config-if)'

# %% [markdown]
# 🤖 Or, we can use [pyATS built-in config classes](https://pubhub.devnetcloud.com/media/genie-feature-browser/docs/#/models) to let it figure out the specifics for our device. We just provide the essential information!

# %%
from genie.conf.base import Interface

new_iosxr_interface = Interface(name="Loopback503", device=device)
new_iosxr_interface.description = "TechTilesDemo02"
rendered_config = new_iosxr_interface.build_config()
print(rendered_config)
# Out:
# 2025-11-12 11:06:03,063: %UNICON-INFO: +++ sandbox1 with via 'cli': configure +++
# configure terminal
# Wed Nov 12 11:53:28.444 UTC
# RP/0/RP0/CPU0:ios(config)#interface Loopback503
# RP/0/RP0/CPU0:ios(config-if)# description TechTilesDemo02
# RP/0/RP0/CPU0:ios(config-if)# exit
# RP/0/RP0/CPU0:ios(config)#commit
# Wed Nov 12 11:53:29.641 UTC
# RP/0/RP0/CPU0:ios(config)#end
# RP/0/RP0/CPU0:ios#
# None

# %% [markdown]
# ✨ **Lovely**. Now, let's **learn** again the interfaces and check **what changed since the last time that we did it**.

# %%
from genie.utils.diff import Diff

learned_interfaces_afterwards = device.learn("interface")
diff = Diff(learned_interfaces.info, learned_interfaces_afterwards.info)
diff.findDiff()
print(diff)
# Out:
# 2025-11-12 11:07:20,594: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show vrf all detail' +++
# show vrf all detail
# Wed Nov 12 11:54:45.796 UTC
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 11:07:21,155: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show interface detail' +++
# show interface detail
# Wed Nov 12 11:54:46.478 UTC
# Loopback100 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: ***TEST LOOPBACK****
#   Internet address is 1.1.1.100/32
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:51:52
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback200 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:34:55
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback300 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:34:55
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback401 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: "TechTilesDemo01"
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:03:58
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback503 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: TechTilesDemo02
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:01:16
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback555 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: PRUEBA_KV
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:51:52
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Null0 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Null interface
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability 255/255, txload Unknown, rxload Unknown
#   Encapsulation Null,  loopback not set,
#   Last link flapped 00:52:20
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#
# MgmtEth0/RP0/CPU0/0 is up, line protocol is up
#   Interface state transitions: 3
#   Hardware is Management Ethernet, address is 0050.56bf.d307 (bia 0050.56bf.d307)
#   Internet address is 10.10.20.175/24
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Full-duplex, 1000Mb/s, CX, link type is autonegotiation
#   loopback not set,
#   Last link flapped 00:51:51
#   ARP type ARPA, ARP timeout 04:00:00
#   Last input 00:00:00, output 00:00:00
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 1 packets/sec
#   5 minute output rate 2000 bits/sec, 1 packets/sec
#      2365 packets input, 221945 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 1 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      1784 packets output, 515793 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      3 carrier transitions
#
# GigabitEthernet0/0/0/0 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.bb17 (bia 0050.56bf.bb17)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/1 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.1337 (bia 0050.56bf.1337)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/2 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.8181 (bia 0050.56bf.8181)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/3 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.afc9 (bia 0050.56bf.afc9)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/4 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.bedb (bia 0050.56bf.bedb)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/5 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.3ee8 (bia 0050.56bf.3ee8)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/6 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.ee29 (bia 0050.56bf.ee29)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
#
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 11:07:22,217: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ethernet tags' +++
# show ethernet tags
# Wed Nov 12 11:54:47.415 UTC
# St:    AD - Administratively Down, Dn - Down, Up - Up
# Ly:    L2 - Switched layer 2 service, L3 = Terminated layer 3 service,
# Xtra   C - Match on Cos, E  - Match on Ethertype, M - Match on source MAC
# -,+:   Ingress rewrite operation; number of tags to pop and push respectively
#
# Interface               St  MTU  Ly Outer            Inner            Xtra -,+
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 11:07:22,762: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show interfaces accounting' +++
# show interfaces accounting
# Wed Nov 12 11:54:47.959 UTC
# No accounting statistics available for Loopback100
#
# No accounting statistics available for Loopback200
#
# No accounting statistics available for Loopback300
#
# No accounting statistics available for Loopback401
#
# No accounting statistics available for Loopback503
#
# No accounting statistics available for Loopback555
#
# No accounting statistics available for Null0
#
# No accounting statistics available for GigabitEthernet0/0/0/0
#
# No accounting statistics available for GigabitEthernet0/0/0/1
#
# No accounting statistics available for GigabitEthernet0/0/0/2
#
# No accounting statistics available for GigabitEthernet0/0/0/3
#
# No accounting statistics available for GigabitEthernet0/0/0/4
#
# No accounting statistics available for GigabitEthernet0/0/0/5
#
# No accounting statistics available for GigabitEthernet0/0/0/6
#
# MgmtEth0/RP0/CPU0/0
#   Protocol              Pkts In         Chars In     Pkts Out        Chars Out
#   IPV4_UNICAST             2373           222549         1789           506613
#   ARP                        19             1140           20              840
#
#
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 11:07:23,374: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ipv4 vrf all interface' +++
# show ipv4 vrf all interface
# Wed Nov 12 11:54:48.584 UTC
# Loopback100 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet address is 1.1.1.100/32
#   MTU is 1500 (1500 is available to IP)
#   Helper address is not set
#   Directed broadcast forwarding is disabled
#   Outgoing access list is not set
#   Inbound  common access list is not set, access list is not set
#   Proxy ARP is disabled
#   ICMP redirects are never sent
#   ICMP unreachables are always sent
#   ICMP mask replies are never sent
#   Table Id is 0xe0000000
# Loopback200 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# Loopback300 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# Loopback401 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# Loopback503 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# Loopback555 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# MgmtEth0/RP0/CPU0/0 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet address is 10.10.20.175/24
#   MTU is 1514 (1500 is available to IP)
#   Helper address is not set
#   Directed broadcast forwarding is disabled
#   Outgoing access list is not set
#   Inbound  common access list is not set, access list is not set
#   Proxy ARP is disabled
#   ICMP redirects are never sent
#   ICMP unreachables are always sent
#   ICMP mask replies are never sent
#   Table Id is 0xe0000000
# GigabitEthernet0/0/0/0 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/1 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/2 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/3 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/4 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/5 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/6 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 11:07:24,079: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ipv6 vrf all interface' +++
# show ipv6 vrf all interface
# Wed Nov 12 11:54:49.291 UTC
# Loopback100 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback200 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback300 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback401 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback503 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback555 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# MgmtEth0/RP0/CPU0/0 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/0 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/1 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/2 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/3 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/4 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/5 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/6 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# RP/0/RP0/CPU0:ios#
# +Loopback401:
# + bandwidth: 0
# + description: "TechTilesDemo01"
# + enabled: True
# + encapsulation:
# +  encapsulation: loopback
# + ipv6:
# +  enabled: True
# + mtu: 1500
# + oper_status: up
# +Loopback503:
# + bandwidth: 0
# + description: TechTilesDemo02
# + enabled: True
# + encapsulation:
# +  encapsulation: loopback
# + ipv6:
# +  enabled: True
# + mtu: 1500
# + oper_status: up
#  MgmtEth0/RP0/CPU0/0:
#   accounting:
#    arp:
# -   chars_in: 1020
# +   chars_in: 1140
# -   chars_out: 756
# +   chars_out: 840
# -   pkts_in: 17
# +   pkts_in: 19
# -   pkts_out: 18
# +   pkts_out: 20
#    ipv4_unicast:
# -   chars_in: 174578
# +   chars_in: 222549
# -   chars_out: 309920
# +   chars_out: 506613
# -   pkts_in: 1862
# +   pkts_in: 2373
# -   pkts_out: 1363
# +   pkts_out: 1789
#   counters:
# -  in_octets: 174034
# +  in_octets: 221945
# -  in_pkts: 1855
# +  in_pkts: 2365
# -  out_octets: 314410
# +  out_octets: 515793
# -  out_pkts: 1359
# +  out_pkts: 1784
#    rate:
# -   out_rate: 0
# +   out_rate: 2000
# -   out_rate_pkts: 0
# +   out_rate_pkts: 1

# %% [markdown]
# ➕ Noice! So we see in this diff that two new interfaces were created.

# %% [markdown]
# 🔥 But now, we want to wipe clean our changes. We can easily retrieve the configurations applied by pyATS and remove them!

# %%
iface = device.interfaces.get("Loopback503")
rollback_config = iface.build_unconfig()
print(rollback_config)
# Out:
# 2025-11-12 11:11:12,956: %UNICON-INFO: +++ sandbox1 with via 'cli': configure +++
# configure terminal
# Wed Nov 12 11:58:38.306 UTC
# RP/0/RP0/CPU0:ios(config)#no interface Loopback503
# RP/0/RP0/CPU0:ios(config)#commit
# Wed Nov 12 11:58:38.893 UTC
# RP/0/RP0/CPU0:ios(config)#end
# RP/0/RP0/CPU0:ios#
# None

# %% [markdown]
# 🧹 Stunning. The other interface, however, needs to be rolled back manually as it was not created using the pyATS models, and our device instance doesn't keep track of it for rollback.

# %%
device.configure('''
    no interface Loopback401
''')
# Out:
# 2025-11-12 11:12:32,126: %UNICON-INFO: +++ sandbox1 with via 'cli': configure +++
# configure terminal
# Wed Nov 12 11:59:57.469 UTC
# RP/0/RP0/CPU0:ios(config)#
# RP/0/RP0/CPU0:ios(config)#    no interface Loopback401
# RP/0/RP0/CPU0:ios(config)#commit
# Wed Nov 12 11:59:58.511 UTC
# RP/0/RP0/CPU0:ios(config)#end
# RP/0/RP0/CPU0:ios#
# '\r\n\rRP/0/RP0/CPU0:ios(config)    no interface Loopback401\r\n\rRP/0/RP0/CPU0:ios(config)commit\r\n\rWed Nov 12 11:59:58.511 UTC\r\nRP/0/RP0/CPU0:ios(config)'

# %%
# !pyats validate testbed pyATS/testbed.yaml --connect
# Out:
# Loading testbed file: pyATS/testbed.yaml
# --------------------------------------------------------------------------------
#
# Testbed Name:
#     NetworkAutoDemo
#
# Testbed Devices:
# .
# `-- sandbox1 [iosxr/ASR9K]
#
# YAML Lint Messages
# ------------------
#
# Connection Check
# ----------------
#
#     note that connection checks are not 100% accurate - it does not take
#     into account that connection implementations may choose to interpret
#     the entire connection block differently.
#
#     For example - Unicon autouses A/B console/standby, but does not allow
#     explicit connection to B.
#
#  - sandbox1/cli             [PASSED]
#
# Warning Messages
# ----------------
#  - Device 'sandbox1' has no interface definitions

# %%
import json
from pyats.topology import loader

# %%
testbed = loader.load('pyATS/testbed.yaml')
device = testbed.devices['sandbox1']

device.connect()
print("✅ Connected successfully to", device.name)
# Out:
# 2025-11-12 10:18:15,318: %UNICON-INFO: +++ sandbox1 logfile sandbox1-cli-1762942695.log +++
#
# 2025-11-12 10:18:15,319: %UNICON-INFO: +++ Unicon plugin iosxr (unicon.plugins.iosxr) +++
#
# Hello there! Hoping you are having a great day
# ... Welcome to 'ios',
# your favorite CISCO.IOSXR.IOSXR Sandbox
#
#
#
# 2025-11-12 10:18:16,857: %UNICON-INFO: +++ connection to spawn: ssh -l admin 131.226.217.150 -p 22, id: 4681864848 +++
#
# 2025-11-12 10:18:16,859: %UNICON-INFO: connection to sandbox1
# (admin@131.226.217.150) Password:
#
#
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:18:17,748: %UNICON-INFO: Storing credentials from default as current_credentials
#
# 2025-11-12 10:18:17,749: %UNICON-WARNING: Invalid hostname detected: found ios, expected sandbox1
#
# 2025-11-12 10:18:17,750: %UNICON-INFO: +++ initializing handle +++
#
# 2025-11-12 10:18:17,928: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'terminal length 0' +++
# terminal length 0
# Wed Nov 12 11:05:43.073 UTC
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:18:18,467: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'terminal width 0' +++
# terminal width 0
# Wed Nov 12 11:05:43.628 UTC
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:18:18,818: %UNICON-INFO: +++ sandbox1 with via 'cli': configure +++
# configure terminal
# Wed Nov 12 11:05:44.144 UTC
# RP/0/RP0/CPU0:ios(config)#no logging console
# RP/0/RP0/CPU0:ios(config)#logging console disable
# RP/0/RP0/CPU0:ios(config)#line console
# RP/0/RP0/CPU0:ios(config-line)#exec-timeout 0 0
# RP/0/RP0/CPU0:ios(config-line)#absolute-timeout 0
# RP/0/RP0/CPU0:ios(config-line)#session-timeout 0
# RP/0/RP0/CPU0:ios(config-line)#line default
# RP/0/RP0/CPU0:ios(config-line)#exec-timeout 0 0
# RP/0/RP0/CPU0:ios(config-line)#absolute-timeout 0
# RP/0/RP0/CPU0:ios(config-line)#session-timeout 0
# RP/0/RP0/CPU0:ios(config-line)#commit
# Wed Nov 12 11:05:46.438 UTC
# RP/0/RP0/CPU0:ios(config-line)#end
# RP/0/RP0/CPU0:ios#
# ✅ Connected successfully to sandbox1

# %%
device.execute("show ip interface brief")
# Out:
# 2025-11-12 09:32:43,037: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ip interface brief' +++
# show ip interface brief
# Wed Nov 12 10:20:08.849 UTC
#
# Interface                      IP-Address      Status          Protocol Vrf-Name
# Loopback100                    1.1.1.100       Up              Up       default
# Loopback555                    unassigned      Up              Up       default
# MgmtEth0/RP0/CPU0/0            10.10.20.175    Up              Up       default
# GigabitEthernet0/0/0/0         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/1         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/2         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/3         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/4         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/5         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/6         unassigned      Shutdown        Down     default
# RP/0/RP0/CPU0:ios#
# '\rWed Nov 12 10:20:08.849 UTC\r\n\r\nInterface                      IP-Address      Status          Protocol Vrf-Name\r\nLoopback100                    1.1.1.100       Up              Up       default \r\nLoopback555                    unassigned      Up              Up       default \r\nMgmtEth0/RP0/CPU0/0            10.10.20.175    Up              Up       default \r\nGigabitEthernet0/0/0/0         unassigned      Shutdown        Down     default \r\nGigabitEthernet0/0/0/1         unassigned      Shutdown        Down     default \r\nGigabitEthernet0/0/0/2         unassigned      Shutdown        Down     default \r\nGigabitEthernet0/0/0/3         unassigned      Shutdown        Down     default \r\nGigabitEthernet0/0/0/4         unassigned      Shutdown        Down     default \r\nGigabitEthernet0/0/0/5         unassigned      Shutdown        Down     default \r\nGigabitEthernet0/0/0/6         unassigned      Shutdown        Down     default'

# %%
genie_parsed_interfaces = device.parse("show ip interface brief")
print(json.dumps(genie_parsed_interfaces,indent=4))
# Out:
# 2025-11-12 09:35:56,067: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ip interface brief' +++
# show ip interface brief
# Wed Nov 12 10:23:21.875 UTC
#
# Interface                      IP-Address      Status          Protocol Vrf-Name
# Loopback100                    1.1.1.100       Up              Up       default
# Loopback555                    unassigned      Up              Up       default
# MgmtEth0/RP0/CPU0/0            10.10.20.175    Up              Up       default
# GigabitEthernet0/0/0/0         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/1         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/2         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/3         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/4         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/5         unassigned      Shutdown        Down     default
# GigabitEthernet0/0/0/6         unassigned      Shutdown        Down     default
# RP/0/RP0/CPU0:ios#
# {
#     "interface": {
#         "Loopback100": {
#             "ip_address": "1.1.1.100",
#             "interface_status": "Up",
#             "protocol_status": "Up",
#             "vrf_name": "default"
#         },
#         "Loopback555": {
#             "ip_address": "unassigned",
#             "interface_status": "Up",
#             "protocol_status": "Up",
#             "vrf_name": "default"
#         },
#         "MgmtEth0/RP0/CPU0/0": {
#             "ip_address": "10.10.20.175",
#             "interface_status": "Up",
#             "protocol_status": "Up",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/0": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/1": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/2": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/3": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/4": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/5": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         },
#         "GigabitEthernet0/0/0/6": {
#             "ip_address": "unassigned",
#             "interface_status": "Shutdown",
#             "protocol_status": "Down",
#             "vrf_name": "default"
#         }
#     }
# }

# %%
learned_interfaces = device.learn("interface")
print(f"\n\n\n\n\n\n\n{json.dumps(learned_interfaces.to_dict(),indent=4)}")
# Out:
# 2025-11-12 09:45:04,568: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show vrf all detail' +++
# show vrf all detail
# Wed Nov 12 10:32:30.358 UTC
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 09:45:05,098: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show interface detail' +++
# show interface detail
# Wed Nov 12 10:32:30.916 UTC
# Loopback100 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: ***TEST LOOPBACK****
#   Internet address is 1.1.1.100/32
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 14:17:57
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback555 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: PRUEBA_KV
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 14:17:57
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Null0 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Null interface
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability 255/255, txload Unknown, rxload Unknown
#   Encapsulation Null,  loopback not set,
#   Last link flapped 14:18:25
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#
# MgmtEth0/RP0/CPU0/0 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Management Ethernet, address is 0050.56bf.d307 (bia 0050.56bf.d307)
#   Internet address is 10.10.20.175/24
#   MTU 1514 bytes, BW 0 Kbit
#      reliability 255/255, txload Unknown, rxload Unknown
#   Encapsulation ARPA,
#   Duplex unknown, 0Kb/s, CX, link type is autonegotiation
#   loopback not set,
#   Last link flapped 14:17:56
#   ARP type ARPA, ARP timeout 04:00:00
#   Last input 00:00:00, output 00:00:00
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 1 packets/sec
#   5 minute output rate 2000 bits/sec, 1 packets/sec
#      24625 packets input, 2796269 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      16882 packets output, 3533379 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      1 carrier transitions
#
# GigabitEthernet0/0/0/0 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.bb17 (bia 0050.56bf.bb17)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/1 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.1337 (bia 0050.56bf.1337)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/2 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.8181 (bia 0050.56bf.8181)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/3 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.afc9 (bia 0050.56bf.afc9)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/4 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.bedb (bia 0050.56bf.bedb)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/5 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.3ee8 (bia 0050.56bf.3ee8)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/6 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.ee29 (bia 0050.56bf.ee29)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
#
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 09:45:05,926: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ethernet tags' +++
# show ethernet tags
# Wed Nov 12 10:32:31.738 UTC
# St:    AD - Administratively Down, Dn - Down, Up - Up
# Ly:    L2 - Switched layer 2 service, L3 = Terminated layer 3 service,
# Xtra   C - Match on Cos, E  - Match on Ethertype, M - Match on source MAC
# -,+:   Ingress rewrite operation; number of tags to pop and push respectively
#
# Interface               St  MTU  Ly Outer            Inner            Xtra -,+
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 09:45:06,461: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show interfaces accounting' +++
# show interfaces accounting
# Wed Nov 12 10:32:32.271 UTC
# No accounting statistics available for Loopback100
#
# No accounting statistics available for Loopback555
#
# No accounting statistics available for Null0
#
# No accounting statistics available for GigabitEthernet0/0/0/0
#
# No accounting statistics available for GigabitEthernet0/0/0/1
#
# No accounting statistics available for GigabitEthernet0/0/0/2
#
# No accounting statistics available for GigabitEthernet0/0/0/3
#
# No accounting statistics available for GigabitEthernet0/0/0/4
#
# No accounting statistics available for GigabitEthernet0/0/0/5
#
# No accounting statistics available for GigabitEthernet0/0/0/6
#
# MgmtEth0/RP0/CPU0/0
#   Protocol              Pkts In         Chars In     Pkts Out        Chars Out
#   IPV4_UNICAST            24490          2788293        16743          3306347
#   ARP                       155             9300          156             6552
#
#
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 09:45:07,103: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ipv4 vrf all interface' +++
# show ipv4 vrf all interface
# Wed Nov 12 10:32:32.910 UTC
# Loopback100 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet address is 1.1.1.100/32
#   MTU is 1500 (1500 is available to IP)
#   Helper address is not set
#   Directed broadcast forwarding is disabled
#   Outgoing access list is not set
#   Inbound  common access list is not set, access list is not set
#   Proxy ARP is disabled
#   ICMP redirects are never sent
#   ICMP unreachables are always sent
#   ICMP mask replies are never sent
#   Table Id is 0xe0000000
# Loopback555 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# MgmtEth0/RP0/CPU0/0 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet address is 10.10.20.175/24
#   MTU is 1514 (1500 is available to IP)
#   Helper address is not set
#   Directed broadcast forwarding is disabled
#   Outgoing access list is not set
#   Inbound  common access list is not set, access list is not set
#   Proxy ARP is disabled
#   ICMP redirects are never sent
#   ICMP unreachables are always sent
#   ICMP mask replies are never sent
#   Table Id is 0xe0000000
# GigabitEthernet0/0/0/0 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/1 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/2 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/3 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/4 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/5 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/6 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 09:45:07,800: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ipv6 vrf all interface' +++
# show ipv6 vrf all interface
# Wed Nov 12 10:32:33.624 UTC
# Loopback100 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback555 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# MgmtEth0/RP0/CPU0/0 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/0 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/1 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/2 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/3 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/4 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/5 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/6 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# RP/0/RP0/CPU0:ios#
#
#
#
#
#
#
#
# {
#     "context_manager": {},
#     "attributes": null,
#     "commands": null,
#     "connections": null,
#     "raw_data": false,
#     "info": {
#         "GigabitEthernet0/0/0/2": {
#             "description": "test",
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.8181",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.8181",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "GigabitEthernet0/0/0/1": {
#             "description": "test",
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.1337",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.1337",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "Loopback555": {
#             "description": "PRUEBA_KV",
#             "oper_status": "up",
#             "mtu": 1500,
#             "enabled": true,
#             "bandwidth": 0,
#             "encapsulation": {
#                 "encapsulation": "loopback"
#             },
#             "ipv6": {
#                 "enabled": true
#             }
#         },
#         "Loopback100": {
#             "description": "***TEST LOOPBACK****",
#             "oper_status": "up",
#             "mtu": 1500,
#             "enabled": true,
#             "bandwidth": 0,
#             "ipv4": {
#                 "1.1.1.100/32": {
#                     "ip": "1.1.1.100",
#                     "prefix_length": "32"
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "loopback"
#             },
#             "ipv6": {
#                 "enabled": true
#             }
#         },
#         "GigabitEthernet0/0/0/6": {
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.ee29",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.ee29",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "GigabitEthernet0/0/0/5": {
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.3ee8",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.3ee8",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "GigabitEthernet0/0/0/4": {
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.bedb",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.bedb",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "GigabitEthernet0/0/0/3": {
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.afc9",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.afc9",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "GigabitEthernet0/0/0/0": {
#             "type": "gigabitethernet",
#             "oper_status": "down",
#             "phys_address": "0050.56bf.bb17",
#             "mtu": 1514,
#             "enabled": false,
#             "mac_address": "0050.56bf.bb17",
#             "bandwidth": 1000000,
#             "flow_control": {
#                 "flow_control_send": false,
#                 "flow_control_receive": false
#             },
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "in_crc_errors": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": false
#             }
#         },
#         "MgmtEth0/RP0/CPU0/0": {
#             "type": "management ethernet",
#             "oper_status": "up",
#             "phys_address": "0050.56bf.d307",
#             "port_speed": "0",
#             "mtu": 1514,
#             "enabled": true,
#             "mac_address": "0050.56bf.d307",
#             "auto_negotiate": true,
#             "duplex_mode": "duplex unknown",
#             "bandwidth": 0,
#             "accounting": {
#                 "ipv4_unicast": {
#                     "pkts_in": 24490,
#                     "chars_in": 2788293,
#                     "pkts_out": 16743,
#                     "chars_out": 3306347
#                 },
#                 "arp": {
#                     "pkts_in": 155,
#                     "chars_in": 9300,
#                     "pkts_out": 156,
#                     "chars_out": 6552
#                 }
#             },
#             "ipv4": {
#                 "10.10.20.175/24": {
#                     "ip": "10.10.20.175",
#                     "prefix_length": "24"
#                 }
#             },
#             "counters": {
#                 "in_pkts": 24625,
#                 "in_octets": 2796269,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 3533379,
#                 "in_crc_errors": 0,
#                 "out_pkts": 16882,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "out_errors": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 1,
#                     "out_rate": 2000,
#                     "out_rate_pkts": 1
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "arpa"
#             },
#             "ipv6": {
#                 "enabled": true
#             }
#         },
#         "Null0": {
#             "type": "null",
#             "oper_status": "up",
#             "mtu": 1500,
#             "enabled": true,
#             "bandwidth": 0,
#             "counters": {
#                 "in_pkts": 0,
#                 "in_octets": 0,
#                 "in_broadcast_pkts": 0,
#                 "in_multicast_pkts": 0,
#                 "in_discards": 0,
#                 "out_octets": 0,
#                 "out_pkts": 0,
#                 "out_broadcast_pkts": 0,
#                 "out_multicast_pkts": 0,
#                 "last_clear": "never",
#                 "rate": {
#                     "load_interval": 300,
#                     "in_rate": 0,
#                     "in_rate_pkts": 0,
#                     "out_rate": 0,
#                     "out_rate_pkts": 0
#                 }
#             },
#             "encapsulation": {
#                 "encapsulation": "null"
#             }
#         }
#     }
# }

# %%
device.configure('''
    interface Loopback401
    description "TechTilesDemo01"
''')
# Out:
# 2025-11-12 09:47:49,769: %UNICON-INFO: +++ sandbox1 with via 'cli': configure +++
# configure terminal
# Wed Nov 12 10:35:15.738 UTC
# RP/0/RP0/CPU0:ios(config)#
# RP/0/RP0/CPU0:ios(config)#    interface Loopback401
# RP/0/RP0/CPU0:ios(config-if)#    description "TechTilesDemo01"
# RP/0/RP0/CPU0:ios(config-if)#commit
# Wed Nov 12 10:35:16.783 UTC
# RP/0/RP0/CPU0:ios(config-if)#end
# RP/0/RP0/CPU0:ios#
# '\r\n\rRP/0/RP0/CPU0:ios(config)    interface Loopback401\r\n\rRP/0/RP0/CPU0:ios(config-if)    description "TechTilesDemo01"\r\n\rRP/0/RP0/CPU0:ios(config-if)commit\r\n\rWed Nov 12 10:35:16.783 UTC\r\nRP/0/RP0/CPU0:ios(config-if)'

# %%
from genie.conf.base import Interface

new_iosxr_interface = Interface(name="Loopback503", device=device)
new_iosxr_interface.description = "TechTilesDemo02"
rendered_config = new_iosxr_interface.build_config()
print(rendered_config)
# Out:
# 2025-11-12 10:31:46,304: %UNICON-INFO: +++ sandbox1 with via 'cli': configure +++
# configure terminal
# Wed Nov 12 11:19:11.648 UTC
# Current Configuration Session  Line       User     Date                     Lock
# 00001000-00002d6d-00000000     vty1       admin    Wed Nov 12 11:17:57 2025
# RP/0/RP0/CPU0:ios(config)#interface Loopback503
# RP/0/RP0/CPU0:ios(config-if)# description TechTilesDemo02
# RP/0/RP0/CPU0:ios(config-if)# exit
# RP/0/RP0/CPU0:ios(config)#commit
# Wed Nov 12 11:19:12.665 UTC
# RP/0/RP0/CPU0:ios(config)#end
# RP/0/RP0/CPU0:ios#
# None

# %%
from genie.utils.diff import Diff

learned_interfaces_afterwards = device.learn("interface")
diff = Diff(learned_interfaces.info, learned_interfaces_afterwards.info)
diff.findDiff()
print(diff)
# Out:
# 2025-11-12 10:31:53,979: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show vrf all detail' +++
# show vrf all detail
# Wed Nov 12 11:19:19.118 UTC
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:31:54,531: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show interface detail' +++
# show interface detail
# Wed Nov 12 11:19:19.696 UTC
# Loopback100 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: ***TEST LOOPBACK****
#   Internet address is 1.1.1.100/32
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:16:25
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback503 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: TechTilesDemo02
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:00:07
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback555 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: PRUEBA_KV
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:16:25
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Null0 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Null interface
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability 255/255, txload Unknown, rxload Unknown
#   Encapsulation Null,  loopback not set,
#   Last link flapped 00:16:54
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#
# MgmtEth0/RP0/CPU0/0 is up, line protocol is up
#   Interface state transitions: 3
#   Hardware is Management Ethernet, address is 0050.56bf.d307 (bia 0050.56bf.d307)
#   Internet address is 10.10.20.175/24
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Full-duplex, 1000Mb/s, CX, link type is autonegotiation
#   loopback not set,
#   Last link flapped 00:16:24
#   ARP type ARPA, ARP timeout 04:00:00
#   Last input 00:00:00, output 00:00:00
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 1 packets/sec
#   5 minute output rate 1000 bits/sec, 1 packets/sec
#      815 packets input, 72865 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 1 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      614 packets output, 172990 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      3 carrier transitions
#
# GigabitEthernet0/0/0/0 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.bb17 (bia 0050.56bf.bb17)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/1 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.1337 (bia 0050.56bf.1337)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/2 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.8181 (bia 0050.56bf.8181)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/3 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.afc9 (bia 0050.56bf.afc9)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/4 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.bedb (bia 0050.56bf.bedb)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/5 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.3ee8 (bia 0050.56bf.3ee8)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/6 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.ee29 (bia 0050.56bf.ee29)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
#
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:31:55,352: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ethernet tags' +++
# show ethernet tags
# Wed Nov 12 11:19:20.511 UTC
# St:    AD - Administratively Down, Dn - Down, Up - Up
# Ly:    L2 - Switched layer 2 service, L3 = Terminated layer 3 service,
# Xtra   C - Match on Cos, E  - Match on Ethertype, M - Match on source MAC
# -,+:   Ingress rewrite operation; number of tags to pop and push respectively
#
# Interface               St  MTU  Ly Outer            Inner            Xtra -,+
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:31:55,903: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show interfaces accounting' +++
# show interfaces accounting
# Wed Nov 12 11:19:21.049 UTC
# No accounting statistics available for Loopback100
#
# No accounting statistics available for Loopback503
#
# No accounting statistics available for Loopback555
#
# No accounting statistics available for Null0
#
# No accounting statistics available for GigabitEthernet0/0/0/0
#
# No accounting statistics available for GigabitEthernet0/0/0/1
#
# No accounting statistics available for GigabitEthernet0/0/0/2
#
# No accounting statistics available for GigabitEthernet0/0/0/3
#
# No accounting statistics available for GigabitEthernet0/0/0/4
#
# No accounting statistics available for GigabitEthernet0/0/0/5
#
# No accounting statistics available for GigabitEthernet0/0/0/6
#
# MgmtEth0/RP0/CPU0/0
#   Protocol              Pkts In         Chars In     Pkts Out        Chars Out
#   IPV4_UNICAST              825            73589          621           178426
#   ARP                        11              660           12              504
#
#
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:31:56,477: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ipv4 vrf all interface' +++
# show ipv4 vrf all interface
# Wed Nov 12 11:19:21.638 UTC
# Loopback100 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet address is 1.1.1.100/32
#   MTU is 1500 (1500 is available to IP)
#   Helper address is not set
#   Directed broadcast forwarding is disabled
#   Outgoing access list is not set
#   Inbound  common access list is not set, access list is not set
#   Proxy ARP is disabled
#   ICMP redirects are never sent
#   ICMP unreachables are always sent
#   ICMP mask replies are never sent
#   Table Id is 0xe0000000
# Loopback503 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# Loopback555 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# MgmtEth0/RP0/CPU0/0 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet address is 10.10.20.175/24
#   MTU is 1514 (1500 is available to IP)
#   Helper address is not set
#   Directed broadcast forwarding is disabled
#   Outgoing access list is not set
#   Inbound  common access list is not set, access list is not set
#   Proxy ARP is disabled
#   ICMP redirects are never sent
#   ICMP unreachables are always sent
#   ICMP mask replies are never sent
#   Table Id is 0xe0000000
# GigabitEthernet0/0/0/0 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/1 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/2 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/3 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/4 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/5 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/6 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:31:57,168: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ipv6 vrf all interface' +++
# show ipv6 vrf all interface
# Wed Nov 12 11:19:22.329 UTC
# Loopback100 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback503 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback555 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# MgmtEth0/RP0/CPU0/0 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/0 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/1 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/2 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/3 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/4 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/5 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/6 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# RP/0/RP0/CPU0:ios#
# +Loopback503:
# + bandwidth: 0
# + description: TechTilesDemo02
# + enabled: True
# + encapsulation:
# +  encapsulation: loopback
# + ipv6:
# +  enabled: True
# + mtu: 1500
# + oper_status: up
#  GigabitEthernet0/0/0/3:
# + description: test
#  MgmtEth0/RP0/CPU0/0:
#   accounting:
#    arp:
# -   chars_in: 9300
# +   chars_in: 660
# -   chars_out: 6552
# +   chars_out: 504
# -   pkts_in: 155
# +   pkts_in: 11
# -   pkts_out: 156
# +   pkts_out: 12
#    ipv4_unicast:
# -   chars_in: 2788293
# +   chars_in: 73589
# -   chars_out: 3306347
# +   chars_out: 178426
# -   pkts_in: 24490
# +   pkts_in: 825
# -   pkts_out: 16743
# +   pkts_out: 621
# - bandwidth: 0
# + bandwidth: 1000000
#   counters:
# -  in_broadcast_pkts: 0
# +  in_broadcast_pkts: 1
# -  in_octets: 2796269
# +  in_octets: 72865
# -  in_pkts: 24625
# +  in_pkts: 815
# -  out_octets: 3533379
# +  out_octets: 172990
# -  out_pkts: 16882
# +  out_pkts: 614
#    rate:
# -   out_rate: 2000
# +   out_rate: 1000
# - duplex_mode: duplex unknown
# + duplex_mode: full
# - port_speed: 0
# + port_speed: 1000

# %%
interfaces_rollback = [
    "Loopback503"
]

for interface_name in interfaces_rollback:
    iface = device.interfaces.get(interface_name)
    rollback_config = iface.build_unconfig()
    print(rollback_config)
# Out:
# 2025-11-12 10:39:35,603: %UNICON-INFO: +++ sandbox1 with via 'cli': configure +++
# configure terminal
# Wed Nov 12 11:27:00.946 UTC
# RP/0/RP0/CPU0:ios(config)#no interface Loopback503
# RP/0/RP0/CPU0:ios(config)#commit
# Wed Nov 12 11:27:01.555 UTC
# RP/0/RP0/CPU0:ios(config)#end
# RP/0/RP0/CPU0:ios#
# None

# %%
learned = device.learn("interface", refresh=True)
learned.info.keys()
# Out:
# 2025-11-12 10:39:40,330: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show vrf all detail' +++
# show vrf all detail
# Wed Nov 12 11:27:05.529 UTC
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:39:40,919: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show interface detail' +++
# show interface detail
# Wed Nov 12 11:27:06.077 UTC
# Loopback100 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: ***TEST LOOPBACK****
#   Internet address is 1.1.1.100/32
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:24:11
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback200 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:07:15
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback300 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:07:15
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Loopback555 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Loopback interface(s)
#   Description: PRUEBA_KV
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability Unknown, txload Unknown, rxload Unknown
#   Encapsulation Loopback,  loopback not set,
#   Last link flapped 00:24:11
#   Last input Unknown, output Unknown
#   Last clearing of "show interface" counters Unknown
#   Input/output data rate is disabled.
#
# Null0 is up, line protocol is up
#   Interface state transitions: 1
#   Hardware is Null interface
#   Internet address is Unknown
#   MTU 1500 bytes, BW 0 Kbit
#      reliability 255/255, txload Unknown, rxload Unknown
#   Encapsulation Null,  loopback not set,
#   Last link flapped 00:24:40
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#
# MgmtEth0/RP0/CPU0/0 is up, line protocol is up
#   Interface state transitions: 3
#   Hardware is Management Ethernet, address is 0050.56bf.d307 (bia 0050.56bf.d307)
#   Internet address is 10.10.20.175/24
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Full-duplex, 1000Mb/s, CX, link type is autonegotiation
#   loopback not set,
#   Last link flapped 00:24:11
#   ARP type ARPA, ARP timeout 04:00:00
#   Last input 00:00:00, output 00:00:00
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 1 packets/sec
#   5 minute output rate 1000 bits/sec, 1 packets/sec
#      1075 packets input, 96639 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 1 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      815 packets output, 231991 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      3 carrier transitions
#
# GigabitEthernet0/0/0/0 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.bb17 (bia 0050.56bf.bb17)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/1 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.1337 (bia 0050.56bf.1337)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/2 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.8181 (bia 0050.56bf.8181)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/3 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.afc9 (bia 0050.56bf.afc9)
#   Description: test
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/4 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.bedb (bia 0050.56bf.bedb)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/5 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.3ee8 (bia 0050.56bf.3ee8)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
# GigabitEthernet0/0/0/6 is administratively down, line protocol is administratively down
#   Interface state transitions: 0
#   Hardware is GigabitEthernet, address is 0050.56bf.ee29 (bia 0050.56bf.ee29)
#   Internet address is Unknown
#   MTU 1514 bytes, BW 1000000 Kbit (Max: 1000000 Kbit)
#      reliability 255/255, txload 0/255, rxload 0/255
#   Encapsulation ARPA,
#   Duplex unknown, 1000Mb/s, link type is force-up
#   output flow control is off, input flow control is off
#   loopback not set,
#   Last input never, output never
#   Last clearing of "show interface" counters never
#   5 minute input rate 0 bits/sec, 0 packets/sec
#   5 minute output rate 0 bits/sec, 0 packets/sec
#      0 packets input, 0 bytes, 0 total input drops
#      0 drops for unrecognized upper-level protocol
#      Received 0 broadcast packets, 0 multicast packets
#               0 runts, 0 giants, 0 throttles, 0 parity
#      0 input errors, 0 CRC, 0 frame, 0 overrun, 0 ignored, 0 abort
#      0 packets output, 0 bytes, 0 total output drops
#      Output 0 broadcast packets, 0 multicast packets
#      0 output errors, 0 underruns, 0 applique, 0 resets
#      0 output buffer failures, 0 output buffers swapped out
#      0 carrier transitions
#
#
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:39:41,724: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ethernet tags' +++
# show ethernet tags
# Wed Nov 12 11:27:06.894 UTC
# St:    AD - Administratively Down, Dn - Down, Up - Up
# Ly:    L2 - Switched layer 2 service, L3 = Terminated layer 3 service,
# Xtra   C - Match on Cos, E  - Match on Ethertype, M - Match on source MAC
# -,+:   Ingress rewrite operation; number of tags to pop and push respectively
#
# Interface               St  MTU  Ly Outer            Inner            Xtra -,+
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:39:42,279: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show interfaces accounting' +++
# show interfaces accounting
# Wed Nov 12 11:27:07.436 UTC
# No accounting statistics available for Loopback100
#
# No accounting statistics available for Loopback200
#
# No accounting statistics available for Loopback300
#
# No accounting statistics available for Loopback555
#
# No accounting statistics available for Null0
#
# No accounting statistics available for GigabitEthernet0/0/0/0
#
# No accounting statistics available for GigabitEthernet0/0/0/1
#
# No accounting statistics available for GigabitEthernet0/0/0/2
#
# No accounting statistics available for GigabitEthernet0/0/0/3
#
# No accounting statistics available for GigabitEthernet0/0/0/4
#
# No accounting statistics available for GigabitEthernet0/0/0/5
#
# No accounting statistics available for GigabitEthernet0/0/0/6
#
# MgmtEth0/RP0/CPU0/0
#   Protocol              Pkts In         Chars In     Pkts Out        Chars Out
#   IPV4_UNICAST             1088            97573          825           235301
#   ARP                        11              660           12              504
#
#
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:39:42,937: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ipv4 vrf all interface' +++
# show ipv4 vrf all interface
# Wed Nov 12 11:27:08.096 UTC
# Loopback100 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet address is 1.1.1.100/32
#   MTU is 1500 (1500 is available to IP)
#   Helper address is not set
#   Directed broadcast forwarding is disabled
#   Outgoing access list is not set
#   Inbound  common access list is not set, access list is not set
#   Proxy ARP is disabled
#   ICMP redirects are never sent
#   ICMP unreachables are always sent
#   ICMP mask replies are never sent
#   Table Id is 0xe0000000
# Loopback200 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# Loopback300 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# Loopback555 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# MgmtEth0/RP0/CPU0/0 is Up, ipv4 protocol is Up
#   Vrf is default (vrfid 0x60000000)
#   Internet address is 10.10.20.175/24
#   MTU is 1514 (1500 is available to IP)
#   Helper address is not set
#   Directed broadcast forwarding is disabled
#   Outgoing access list is not set
#   Inbound  common access list is not set, access list is not set
#   Proxy ARP is disabled
#   ICMP redirects are never sent
#   ICMP unreachables are always sent
#   ICMP mask replies are never sent
#   Table Id is 0xe0000000
# GigabitEthernet0/0/0/0 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/1 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/2 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/3 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/4 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/5 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# GigabitEthernet0/0/0/6 is Shutdown, ipv4 protocol is Down
#   Vrf is default (vrfid 0x60000000)
#   Internet protocol processing disabled
# RP/0/RP0/CPU0:ios#
#
# 2025-11-12 10:39:43,633: %UNICON-INFO: +++ sandbox1 with via 'cli': executing command 'show ipv6 vrf all interface' +++
# show ipv6 vrf all interface
# Wed Nov 12 11:27:08.810 UTC
# Loopback100 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback200 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback300 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# Loopback555 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# MgmtEth0/RP0/CPU0/0 is Up, ipv6 protocol is Up, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/0 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/1 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/2 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/3 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/4 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/5 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# GigabitEthernet0/0/0/6 is Shutdown, ipv6 protocol is Down, Vrfid is default (0x60000000)
#   IPv6 is disabled, link-local address unassigned
#   No global unicast address is configured
# RP/0/RP0/CPU0:ios#
# dict_keys(['GigabitEthernet0/0/0/3', 'GigabitEthernet0/0/0/2', 'GigabitEthernet0/0/0/1', 'Loopback555', 'Loopback100', 'GigabitEthernet0/0/0/6', 'GigabitEthernet0/0/0/5', 'GigabitEthernet0/0/0/4', 'GigabitEthernet0/0/0/0', 'MgmtEth0/RP0/CPU0/0', 'Null0', 'Loopback300', 'Loopback200'])
